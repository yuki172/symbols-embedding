# %%
# !python train.py --max_epochs=20 --batch_size=16 \
--input_size=128 \
--learning_rate=5e-4
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# ┏━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name            ┃ Type                 ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ backbone        │ Sequential           │ 11.2 M │ train │     0 │
# │ 1 │ projection_head │ SimCLRProjectionHead │  328 K │ train │     0 │
# │ 2 │ criterion       │ NTXentLoss           │      0 │ train │     0 │
# └───┴─────────────────┴──────────────────────┴────────┴───────┴───────┘
# Trainable params: 11.5 M
# Non-trainable params: 0
# Total params: 11.5 M
# Total estimated model params size (MB): 46
# Modules in train mode: 77
# Modules in eval mode: 0
# Total FLOPs: 0
# ...

# %%
# !python train.py --max_epochs=30 --batch_size=32 \
--input_size=128 \
--learning_rate=5e-5
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# ┏━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name            ┃ Type                 ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ backbone        │ Sequential           │ 11.2 M │ train │     0 │
# │ 1 │ projection_head │ SimCLRProjectionHead │  328 K │ train │     0 │
# │ 2 │ criterion       │ NTXentLoss           │      0 │ train │     0 │
# └───┴─────────────────┴──────────────────────┴────────┴───────┴───────┘
# Trainable params: 11.5 M
# Non-trainable params: 0
# Total params: 11.5 M
# Total estimated model params size (MB): 46
# Modules in train mode: 77
# Modules in eval mode: 0
# Total FLOPs: 0
# ...
