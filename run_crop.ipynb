# %%
# !python crop.py --json_path="data/original_data/train/_annotations.coco.json" --images_dir="data/original_data/train" --out_dir="data/train"
# Out:
# 100%|██████████████████████████████████████| 2606/2606 [00:04<00:00, 537.12it/s]
# Saved 2606 crops to data/train

# %%
# !python crop.py --json_path="data/original_data/test/_annotations.coco.json" --images_dir="data/original_data/test" --out_dir="data/test"
# Out:
# 100%|████████████████████████████████████████| 424/424 [00:00<00:00, 479.58it/s]
# Saved 424 crops to data/test
